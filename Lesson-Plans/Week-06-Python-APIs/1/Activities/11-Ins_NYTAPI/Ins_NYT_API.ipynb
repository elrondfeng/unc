# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
from IPython.core.display import display, HTML
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "granola"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=164b73c522a8420c8e05343ef1da0a7e&q=granola'

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles["response"]["docs"]]
pprint(articles_list)
# Out:
# [{'_id': '5a8408c210f40f00018c0e60',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'By MICHAEL POLLAN',
#              'person': [{'firstname': 'Michael',
#                          'lastname': 'POLLAN',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': 'Nonfiction',
#                'kicker': 'Nonfiction',
#                'main': 'How We Got From Twinkies to Tofu',
#                'name': None,
#                'print_headline': 'Granola',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Books and Literature'},
# ...

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    display(HTML(f'<h1>{article["web_url"]}</h1>'))
#     print("<h1>" + article["web_url"] + "</h1>")
# Out:
# Your Reading List
# <h1>https://www.nytimes.com/2018/02/14/books/review/hippie-food-jonathan-kauffman.html</h1>
# <h1>https://topics.nytimes.com/top/news/health/series/recipes_for_health/breakfast_grains/index.html</h1>
# <h1>https://topics.nytimes.com/top/news/health/series/recipes_for_health/flaxseeds/index.html</h1>
# <h1>https://topics.nytimes.com/top/news/health/series/recipes_for_health/substantial_pastries/index.html</h1>
# <h1>https://www.nytimes.com/2018/03/09/dining/what-to-cook-this-weekend-newsletter.html</h1>
# <h1>https://www.nytimes.com/2018/02/28/nyregion/the-sweet-smell-of-osmanthus-absolute.html</h1>
# <h1>https://www.nytimes.com/2018/03/01/technology/bit-by-bit-whole-foods-gets-an-amazon-touch.html</h1>
# <h1>https://www.nytimes.com/2018/02/24/travel/belfast-hotel-review.html</h1>
# <h1>https://www.nytimes.com/2018/01/12/dining/what-to-cook-this-weekend-newsletter.html</h1>
# <h1>https://www.nytimes.com/2018/02/16/business/natural-food-products.html</h1>

# %%
import requests
from pprint import pprint
from config import api_key
from IPython.core.display import display, HTML
url = "https://api.giphy.com/v1/gifs/search?q=cats/&api_key=dc6zaTOxFJmzC&limit=10"
cats = requests.get(url).json()
stuff = cats['data']
for i in stuff:
#     print (i['images']['fixed_width']['url'])
    img = i['images']['fixed_width']['url']
#     print(img)
    display(HTML(f'<img src="{img}" alt="Smiley face" height="100" width="100">'))
# Out:
# <img src="https://media0.giphy.com/media/cfuL5gqFDreXxkWQ4o/200w.gif?cid=e1bb72ff5aad4e4f58536771736aa0b7" alt="Smiley face" height="100" width="100">
# <img src="https://media2.giphy.com/media/Ov5NiLVXT8JEc/200w.gif?cid=e1bb72ff5aad4e4f58536771736aa0b7" alt="Smiley face" height="100" width="100">
# <img src="https://media3.giphy.com/media/aC45M5Q4D07Pq/200w.gif?cid=e1bb72ff5aad4e4f58536771736aa0b7" alt="Smiley face" height="100" width="100">
# <img src="https://media0.giphy.com/media/3o72EX5QZ9N9d51dqo/200w.gif?cid=e1bb72ff5aad4e4f58536771736aa0b7" alt="Smiley face" height="100" width="100">
# <img src="https://media3.giphy.com/media/W3QKEujo8vztC/200w.gif?cid=e1bb72ff5aad4e4f58536771736aa0b7" alt="Smiley face" height="100" width="100">
# <img src="https://media2.giphy.com/media/gl8ymnpv4Sqha/200w.gif?cid=e1bb72ff5aad4e4f58536771736aa0b7" alt="Smiley face" height="100" width="100">
# ...
